# %%
import pandas as pd
import re
import requests
import json

from blog.models import latest_transactions,last_blocks

# %%
def get_blocks():
    last_blocks = requests.get('https://explorer.rise.vision/api/getLastBlocks')
    last_blocks_cleaned = json.loads(last_blocks.content)['blocks']
    df = pd.DataFrame(last_blocks_cleaned)
    lst = []
    for dct in df['delegate'].tolist():
        lst.append((dct['username'],dct['rank']))

    df['username'] = ''
    df['rank']=''
    for ix in range(len(df)):
        df['username'].ix[ix] = lst[ix][0]
        df['rank'].ix[ix] = lst[ix][1]

    df.head(5)
    del df['delegate']
    
    df_cols = [x for x in df.columns.tolist()]
    block_cols = ['generator', 'height','blockid','reward','timestamp','totalamount','totalfee','totalforged','transactionscount','username','rank']
    columns = {x:y for (x,y) in zip(df_cols,block_cols)}
    df.rename(columns=columns,inplace=True)
    
    return df

# %%
def get_transactions():
    last_transactions = requests.get('https://explorer.rise.vision/api/getLastTransactions')
    last_transactions_cleaned = json.loads(last_transactions.content)['transactions']
    zf = pd.DataFrame(last_transactions_cleaned)

    to_del = ['asset','blockId','knownRecipient','knownSender','recipientDelegate','recipientPublicKey','requesterPublicKey','rowId','senderDelegate','senderPublicKey','signSignature','signature','signatures',]
    desired_cols = [x for x in zf.columns.tolist() if x not in to_del]

    zf = zf[desired_cols]

    zf = zf.rename(columns={x[0]:x[1].lower() for x in zip(zf.columns.tolist(),zf.columns.tolist())})

    zf = zf[['id','amount','fee','height','senderid','timestamp','recipientid','type','confirmations']]
    
    sort_me = """
    txid = models.BigIntegerField()
    amount = models.BigIntegerField()
    fee = models.BigIntegerField()
    height = models.BigIntegerField()
    senderid = models.CharField(max_length=50)
    timestamp = models.BigIntegerField()
    recipientid = models.CharField(max_length=50)
    txtype = models.BigIntegerField()
    confirmations = models.BigIntegerField()
    """

    lst = sort_me.split('\n')
    tx_cols = []
    for ix in lst:
        if ix:  
            resp = re.split(' =', ix)
            tx_cols.append(resp[0].strip())
    curr_tx_cols = zf.columns.tolist()
    columns = {x:y for (x,y) in zip(curr_tx_cols, tx_cols)}
    zf.rename(columns = columns, inplace=True)
    return zf

# %%
#inserts lasttx in database
zf = get_transactions()
X = zf.itertuples()
f = open('get_transactions_log','w')

while True:
    try:
        Y = latest_transactions()
        resp = zip(zf.columns.tolist(),X.next()[1:])
    
        for ix in resp:
    
                print ix[0],ix[1]
                if ix != 'id':
                    setattr(Y,str(ix[0]),ix[1])
        Y.save()
    except StopIteration:
        break 
        
    except Exception as e:
        f.write(str(e))
        f.write('\n')
        f.write(str(resp))
        f.write('\n')
f.close()
# Out:
# txid 15888983335462932892
# amount 160454370
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055941
# recipientid 6767990488361591146R
# txtype 0
# confirmations 47
# txid 8215670086647521374
# amount 5679106284
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055940
# recipientid 11289621119705940583R
# txtype 0
# confirmations 47
# txid 14874593631504517225
# amount 22040023
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055939
# recipientid 6859186545500394212R
# txtype 0
# confirmations 47
# txid 14380700881193892308
# amount 25006066
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055938
# recipientid 10852230889329276265R
# txtype 0
# confirmations 47
# txid 14872585253897204128
# amount 23208250
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055937
# recipientid 10312944874082643700R
# txtype 0
# confirmations 47
# txid 3107684928502887095
# amount 34200842
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055936
# recipientid 4176701614364608156R
# txtype 0
# confirmations 47
# txid 15944739831232835883
# amount 71114266
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055935
# recipientid 14264648453055334449R
# txtype 0
# confirmations 47
# txid 491214654252954710
# amount 29185205
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055934
# recipientid 6847087787137145145R
# txtype 0
# confirmations 47
# txid 14959107152476930340
# amount 46007754
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055933
# recipientid 12058607356902584442R
# txtype 0
# confirmations 47
# txid 5224553535974968392
# amount 120178500
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055931
# recipientid 10252930104410603600R
# txtype 0
# confirmations 47
# txid 12313963309480359454
# amount 583001833
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055930
# recipientid 16564798650064767115R
# txtype 0
# confirmations 47
# txid 16408679466341573143
# amount 7532894580
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055929
# recipientid 18386189190083572488R
# txtype 0
# confirmations 47
# txid 1386317615352594641
# amount 3687687271
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055928
# recipientid 13329009822455434517R
# txtype 0
# confirmations 47
# txid 14985356242599095955
# amount 820351050
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055927
# recipientid 3576935034905060278R
# txtype 0
# confirmations 47
# txid 8294286195804493743
# amount 153299582
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055926
# recipientid 17392019702629770589R
# txtype 0
# confirmations 47
# txid 10463478715813424140
# amount 344845589
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055925
# recipientid 8568777364684200854R
# txtype 0
# confirmations 47
# txid 13709104180736195204
# amount 377073180
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055924
# recipientid 15967035077506847753R
# txtype 0
# confirmations 47
# txid 264462697033230629
# amount 1762406414
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055923
# recipientid 10118075187950332137R
# txtype 0
# confirmations 47
# txid 17799636327403232814
# amount 2840915823
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055922
# recipientid 14781128198394017067R
# txtype 0
# confirmations 47
# txid 2653318348788327253
# amount 166613611
# fee 10000000
# height 1346044
# senderid 7889374079483640385R
# timestamp 74055921
# recipientid 11801234659222782981R
# txtype 0
# confirmations 47

# %%
#inserts latestblocks in database
X = df.itertuples()


while True:
    Y = last_blocks()
    resp = zip(df.columns.tolist(),X.next()[1:])
    print resp
    for ix in resp:
    
            print ix[0],ix[1]
            if ix != 'id':
                setattr(Y,str(ix[0]),ix[1])
    Y.save()
# Out:
# [('generator', u'14516754967305007101R'), ('height', 1335289), ('blockid', u'7100474208901727861'), ('reward', 1200000000), ('timestamp', 73710480), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'cacao'), ('rank', 57)]
# generator 14516754967305007101R
# height 1335289
# blockid 7100474208901727861
# reward 1200000000
# timestamp 73710480
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username cacao
# rank 57
# [('generator', u'7889374079483640385R'), ('height', 1335288), ('blockid', u'11569365752903298650'), ('reward', 1200000000), ('timestamp', 73710450), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'stefanoproxy_pool'), ('rank', 24)]
# generator 7889374079483640385R
# height 1335288
# blockid 11569365752903298650
# reward 1200000000
# timestamp 73710450
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username stefanoproxy_pool
# rank 24
# [('generator', u'7128048429618539851R'), ('height', 1335287), ('blockid', u'10744813317631915796'), ('reward', 1200000000), ('timestamp', 73710420), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'lumberjack'), ('rank', 67)]
# generator 7128048429618539851R
# height 1335287
# blockid 10744813317631915796
# reward 1200000000
# timestamp 73710420
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username lumberjack
# rank 67
# [('generator', u'6433343791511456109R'), ('height', 1335286), ('blockid', u'15207303097381745974'), ('reward', 1200000000), ('timestamp', 73710390), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'maxwell_pp2'), ('rank', 22)]
# generator 6433343791511456109R
# height 1335286
# blockid 15207303097381745974
# reward 1200000000
# timestamp 73710390
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username maxwell_pp2
# rank 22
# [('generator', u'5878285715116874995R'), ('height', 1335285), ('blockid', u'12372939645749247110'), ('reward', 1200000000), ('timestamp', 73710360), ('totalamount', 2344928846), ('totalfee', 150000000), ('totalforged', 1350000000), ('transactionscount', 15), ('username', u'realnoah'), ('rank', 78)]
# generator 5878285715116874995R
# height 1335285
# blockid 12372939645749247110
# reward 1200000000
# timestamp 73710360
# totalamount 2344928846
# totalfee 150000000
# totalforged 1350000000
# transactionscount 15
# username realnoah
# rank 78
# [('generator', u'2805328124909722056R'), ('height', 1335284), ('blockid', u'16303926592762003822'), ('reward', 1200000000), ('timestamp', 73710330), ('totalamount', 25175684584), ('totalfee', 210000000), ('totalforged', 1410000000), ('transactionscount', 21), ('username', u'tesla'), ('rank', 100)]
# generator 2805328124909722056R
# height 1335284
# blockid 16303926592762003822
# reward 1200000000
# timestamp 73710330
# totalamount 25175684584
# totalfee 210000000
# totalforged 1410000000
# transactionscount 21
# username tesla
# rank 100
# [('generator', u'8824604891125759686R'), ('height', 1335283), ('blockid', u'14148424260529693454'), ('reward', 1200000000), ('timestamp', 73710300), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'openbitlab'), ('rank', 63)]
# generator 8824604891125759686R
# height 1335283
# blockid 14148424260529693454
# reward 1200000000
# timestamp 73710300
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username openbitlab
# rank 63
# [('generator', u'7271552341706948404R'), ('height', 1335282), ('blockid', u'10295017870072011624'), ('reward', 1200000000), ('timestamp', 73710270), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'shads'), ('rank', 71)]
# generator 7271552341706948404R
# height 1335282
# blockid 10295017870072011624
# reward 1200000000
# timestamp 73710270
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username shads
# rank 71
# [('generator', u'2846361110670259348R'), ('height', 1335281), ('blockid', u'7407691441525070924'), ('reward', 1200000000), ('timestamp', 73710240), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'cct_risearmyxxx'), ('rank', 42)]
# generator 2846361110670259348R
# height 1335281
# blockid 7407691441525070924
# reward 1200000000
# timestamp 73710240
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username cct_risearmyxxx
# rank 42
# [('generator', u'8093718274007724701R'), ('height', 1335280), ('blockid', u'10546517511268497986'), ('reward', 1200000000), ('timestamp', 73710210), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'official_pool'), ('rank', 1)]
# generator 8093718274007724701R
# height 1335280
# blockid 10546517511268497986
# reward 1200000000
# timestamp 73710210
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username official_pool
# rank 1
# [('generator', u'2780996313277825383R'), ('height', 1335279), ('blockid', u'1883727458826490904'), ('reward', 1200000000), ('timestamp', 73710180), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'cct_risearmyx'), ('rank', 6)]
# generator 2780996313277825383R
# height 1335279
# blockid 1883727458826490904
# reward 1200000000
# timestamp 73710180
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username cct_risearmyx
# rank 6
# [('generator', u'12158656918322992282R'), ('height', 1335278), ('blockid', u'6379635013884749917'), ('reward', 1200000000), ('timestamp', 73710150), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'corin'), ('rank', 91)]
# generator 12158656918322992282R
# height 1335278
# blockid 6379635013884749917
# reward 1200000000
# timestamp 73710150
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username corin
# rank 91
# [('generator', u'5527669024087519724R'), ('height', 1335277), ('blockid', u'359306573901512388'), ('reward', 1200000000), ('timestamp', 73710120), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'yoda_pool'), ('rank', 18)]
# generator 5527669024087519724R
# height 1335277
# blockid 359306573901512388
# reward 1200000000
# timestamp 73710120
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username yoda_pool
# rank 18
# [('generator', u'16805196409417127762R'), ('height', 1335276), ('blockid', u'17893230201484159530'), ('reward', 1200000000), ('timestamp', 73710090), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'ccgut'), ('rank', 65)]
# generator 16805196409417127762R
# height 1335276
# blockid 17893230201484159530
# reward 1200000000
# timestamp 73710090
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username ccgut
# rank 65
# [('generator', u'17987993660060650032R'), ('height', 1335275), ('blockid', u'4881160793276437440'), ('reward', 1200000000), ('timestamp', 73710060), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'grandcanyon'), ('rank', 98)]
# generator 17987993660060650032R
# height 1335275
# blockid 4881160793276437440
# reward 1200000000
# timestamp 73710060
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username grandcanyon
# rank 98
# [('generator', u'1304736568675383072R'), ('height', 1335274), ('blockid', u'855018887556164934'), ('reward', 1200000000), ('timestamp', 73710030), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'eastwood'), ('rank', 99)]
# generator 1304736568675383072R
# height 1335274
# blockid 855018887556164934
# reward 1200000000
# timestamp 73710030
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username eastwood
# rank 99
# [('generator', u'12608597047379516196R'), ('height', 1335273), ('blockid', u'4174198856324337859'), ('reward', 1200000000), ('timestamp', 73710000), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'daenerys'), ('rank', 51)]
# generator 12608597047379516196R
# height 1335273
# blockid 4174198856324337859
# reward 1200000000
# timestamp 73710000
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username daenerys
# rank 51
# [('generator', u'1603493449158083086R'), ('height', 1335272), ('blockid', u'8640039554647029283'), ('reward', 1200000000), ('timestamp', 73709970), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'cleopatra'), ('rank', 101)]
# generator 1603493449158083086R
# height 1335272
# blockid 8640039554647029283
# reward 1200000000
# timestamp 73709970
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username cleopatra
# rank 101
# [('generator', u'17153832774092081399R'), ('height', 1335271), ('blockid', u'2916462079950647785'), ('reward', 1200000000), ('timestamp', 73709940), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'alphago'), ('rank', 53)]
# generator 17153832774092081399R
# height 1335271
# blockid 2916462079950647785
# reward 1200000000
# timestamp 73709940
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username alphago
# rank 53
# [('generator', u'4687459964378777960R'), ('height', 1335270), ('blockid', u'10881082088105731649'), ('reward', 1200000000), ('timestamp', 73709910), ('totalamount', 0), ('totalfee', 0), ('totalforged', 1200000000), ('transactionscount', 0), ('username', u'snowman'), ('rank', 58)]
# generator 4687459964378777960R
# height 1335270
# blockid 10881082088105731649
# reward 1200000000
# timestamp 73709910
# totalamount 0
# totalfee 0
# totalforged 1200000000
# transactionscount 0
# username snowman
# rank 58
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-67-84847e407166> in <module>()
#       5 while True:
#       6     Y = last_blocks()
# ----> 7     resp = zip(df.columns.tolist(),X.next()[1:])
#       8     print resp
#       9     for ix in resp:
#
# StopIteration:

# %%
Y.generator
# Out:
# u'7889374079483640385R'

# %%
df.columns.tolist()
# Out:
# [u'generator',
#  u'height',
#  u'id',
#  u'reward',
#  u'timestamp',
#  u'totalAmount',
#  u'totalFee',
#  u'totalForged',
#  u'transactionsCount',
#  'username',
#  'rank']

# %%
X = last_blocks()

# %%
X.generator = 1

# %%
X.height = 23

# %%
df.columns.tolist()
# Out:
# [u'generator',
#  u'height',
#  u'id',
#  u'reward',
#  u'timestamp',
#  u'totalAmount',
#  u'totalFee',
#  u'totalForged',
#  u'transactionsCount',
#  'username',
#  'rank']

# %%
df
# Out:
#                 generator   height               blockid      reward  \
# 0   14516754967305007101R  1335289   7100474208901727861  1200000000
# 1    7889374079483640385R  1335288  11569365752903298650  1200000000
# 2    7128048429618539851R  1335287  10744813317631915796  1200000000
# 3    6433343791511456109R  1335286  15207303097381745974  1200000000
# 4    5878285715116874995R  1335285  12372939645749247110  1200000000
# 5    2805328124909722056R  1335284  16303926592762003822  1200000000
# 6    8824604891125759686R  1335283  14148424260529693454  1200000000
# 7    7271552341706948404R  1335282  10295017870072011624  1200000000
# 8    2846361110670259348R  1335281   7407691441525070924  1200000000
# 9    8093718274007724701R  1335280  10546517511268497986  1200000000
# 10   2780996313277825383R  1335279   1883727458826490904  1200000000
# 11  12158656918322992282R  1335278   6379635013884749917  1200000000
# 12   5527669024087519724R  1335277    359306573901512388  1200000000
# 13  16805196409417127762R  1335276  17893230201484159530  1200000000
# 14  17987993660060650032R  1335275   4881160793276437440  1200000000
# 15   1304736568675383072R  1335274    855018887556164934  1200000000
# 16  12608597047379516196R  1335273   4174198856324337859  1200000000
# 17   1603493449158083086R  1335272   8640039554647029283  1200000000
# 18  17153832774092081399R  1335271   2916462079950647785  1200000000
# 19   4687459964378777960R  1335270  10881082088105731649  1200000000
#
#     timestamp  totalamount   totalfee  totalforged  transactionscount  \
# 0    73710480            0          0   1200000000                  0
# 1    73710450            0          0   1200000000                  0
# 2    73710420            0          0   1200000000                  0
# 3    73710390            0          0   1200000000                  0
# 4    73710360   2344928846  150000000   1350000000                 15
# 5    73710330  25175684584  210000000   1410000000                 21
# 6    73710300            0          0   1200000000                  0
# 7    73710270            0          0   1200000000                  0
# 8    73710240            0          0   1200000000                  0
# 9    73710210            0          0   1200000000                  0
# 10   73710180            0          0   1200000000                  0
# 11   73710150            0          0   1200000000                  0
# 12   73710120            0          0   1200000000                  0
# 13   73710090            0          0   1200000000                  0
# 14   73710060            0          0   1200000000                  0
# 15   73710030            0          0   1200000000                  0
# 16   73710000            0          0   1200000000                  0
# 17   73709970            0          0   1200000000                  0
# 18   73709940            0          0   1200000000                  0
# 19   73709910            0          0   1200000000                  0
#
#              username  rank
# 0               cacao    57
# 1   stefanoproxy_pool    24
# 2          lumberjack    67
# 3         maxwell_pp2    22
# 4            realnoah    78
# 5               tesla   100
# 6          openbitlab    63
# 7               shads    71
# 8     cct_risearmyxxx    42
# 9       official_pool     1
# 10      cct_risearmyx     6
# 11              corin    91
# 12          yoda_pool    18
# 13              ccgut    65
# 14        grandcanyon    98
# 15           eastwood    99
# 16           daenerys    51
# 17          cleopatra   101
# 18            alphago    53
# 19            snowman    58
